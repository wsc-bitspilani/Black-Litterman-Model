# %%
# !pip install -q -U google-genai
# !pip install semopy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.4/206.4 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.2 MB/s eta 0:00:00

# %%
import semopy as sem
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
from google import genai
import os

# %%
def analyze_doc():

  client = genai.Client(api_key="AIzaSyBnTS7-TD9x1X0u8uVt20e4xKeeQH9gVCY")

  #Retrieve PDF
  path = 'concall.pdf'

  file = client.files.upload(file = path)
  prompt = 'Extract KPI data from this. Create graphs or excel for visualization of data, and provide it in good formatting.'

  while True:
    try:
      response = client.models.generate_content(
      model="gemini-2.5-flash",
      contents=[file, prompt])
      print(response.text)
    except genai.errors.ClientError:
      alt_api_key = "AIzaSyCHo742F-1rmoAp1d8ISuFwyAcEgy8DFC4"
      client2 = genai.Client(api_key=alt_api_key)
      response = client2.models.generate_content(
      model="gemini-2.0-flash-thinking-exp-01-21",
      contents=[file, prompt])
      print(response.text)
    except Exception as e:
      print(e)
      return "Error"
    else:
      break
analyze_doc()
# Out:
# Here's a comprehensive extraction of the KPI data from the provided document, structured for easy visualization in graphs or Excel.
#
# ---
#
# ## Trent Limited - Key Performance Indicators (KPIs) Data
#
# All financial values are in ₹ Crore unless otherwise specified.
# All data is for Fiscal Year (FY) ending March 31.
#
# ### 1. Overall Company Performance (FY15 - FY25)
#
# This data can be used to create **Line Charts** or **Bar Charts** to show trends over time.
#
# | Fiscal Year | Total Stores (#) | Sales (incl. GST) (₹ Cr) | PBT (before exceptional items) (₹ Cr) | EPS (₹ Per Share) | Operating ROE* (%) | Operating ROCE* (%) | Gross Fixed Assets (₹ Cr) |
# | :---------- | :--------------- | :----------------------- | :------------------------------------ | :---------------- | :---------------- | :------------------ | :------------------------ |
# ...
